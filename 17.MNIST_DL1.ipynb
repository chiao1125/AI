# %% [markdown]
# ## MNIST資料集深度學習訓練1
# * MNIST為手寫辨識資料集，含有60000筆手寫數字訓練資料，以及10000筆測試資料
# * 本範例利用傳統的深度學習模型進行訓練
# * 可嘗試"變更執行階段"類型為"None"或"GPU"型態(變更後記得重啟執行階段)

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten

# %% [markdown]
# ## 準備資料

# %%
#從keras的預設資料集讀取資料
#x_train:訓練資料 y_train:訓練資料的標籤
#x_test:測試資料 y_train:測試資料的標籤
mnist = keras.datasets.mnist
(x_train, y_train),(x_test, y_test) = mnist.load_data()
print(x_train.shape[0], '個訓練範例')
print(x_test.shape[0], '個測試範例')
#進行正規化以增加正確性
x_train, x_test = x_train / 255.0, x_test / 255.0
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11493376/11490434 [==============================] - 0s 0us/step
# 60000 個訓練範例
# 10000 個測試範例

# %% [markdown]
# ## 定義模型

# %%
model = Sequential()
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ## 進行訓練

# %%
model.fit(x_train, y_train, epochs=5, batch_size=1000)
# Out:
# Epoch 1/5
# 60/60 [==============================] - 3s 6ms/step - loss: 0.9852 - accuracy: 0.7247
# Epoch 2/5
# 60/60 [==============================] - 0s 6ms/step - loss: 0.2607 - accuracy: 0.9249
# Epoch 3/5
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1916 - accuracy: 0.9452
# Epoch 4/5
# 60/60 [==============================] - 0s 5ms/step - loss: 0.1537 - accuracy: 0.9561
# Epoch 5/5
# 60/60 [==============================] - 0s 6ms/step - loss: 0.1246 - accuracy: 0.9651

# %% [markdown]
# ## 利用測試資料評估正確性

# %%
score=model.evaluate(x_test, y_test)
print("正確率為：",score[1])
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.1164 - accuracy: 0.9645
# 正確率為： 0.9645000100135803
